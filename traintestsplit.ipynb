# %%
# import library and dataset
import pandas as pd 
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Diabetes.csv')

# %%
df.head() #check the dataset
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df.columns  #check columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
df.shape  #check the size of the dataset
# Out:
# (768, 9)

# %%
from sklearn.model_selection import train_test_split
X = df.drop('diabetes', axis=1)  #Every column except the output column
y= df['diabetes']  #The output column
print(X.shape , y.shape)
# Out:
# (768, 8) (768,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
y_train.shape
# Out:
# (614,)

# %%
y_test.shape
# Out:
# (154,)
